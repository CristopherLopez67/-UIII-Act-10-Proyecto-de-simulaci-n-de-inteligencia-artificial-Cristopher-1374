# %% [markdown]
# <a href="https://colab.research.google.com/github/CristopherLopez67/-UIII-Act-10-Proyecto-de-simulaci-n-de-inteligencia-artificial-Cristopher-1374/blob/main/UIII_Act_10_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Cristopher Lopez NL = 34 Fecha 25/05/2026
# #### investigador y investigadores

# %%
print("==========================================")
print("   SISTEMA IA DE INVESTIGADORES")
print("==========================================")

# Lista vacía
investigadores = []

# Diccionario vacío
investigador = {}

while True:

    print("\n========= MENU =========")
    print("1. Registrar investigador")
    print("2. Mostrar investigadores")
    print("3. Buscar investigador")
    print("4. Actualizar especialidad")
    print("5. Eliminar investigador")
    print("6. Salir")

    opcion = input("\nSelecciona una opcion: ")

    # OPCION 1
    if opcion == "1":

        investigador = {}

        print("\n--- REGISTRO DE INVESTIGADOR ---")

        nombre = input("Nombre del investigador: ")
        especialidad = input("Especialidad: ")
        proyectos = input("Cantidad de proyectos: ")

        investigador["nombre"] = nombre
        investigador["especialidad"] = especialidad
        investigador["proyectos"] = proyectos

        investigadores.append(investigador)

        print("\nIA: Investigador registrado correctamente.")

    # OPCION 2
    elif opcion == "2":

        print("\n--- LISTA DE INVESTIGADORES ---")

        if len(investigadores) == 0:
            print("No hay investigadores registrados.")

        else:
            contador = 1

            for dato in investigadores:

                print("\nInvestigador", contador)
                print("Nombre:", dato["nombre"])
                print("Especialidad:", dato["especialidad"])
                print("Proyectos:", dato["proyectos"])

                contador += 1

    # OPCION 3
    elif opcion == "3":

        buscar = input("\nEscribe el nombre del investigador: ")

        encontrado = False

        for dato in investigadores:

            if dato["nombre"] == buscar:

                print("\n--- INVESTIGADOR ENCONTRADO ---")
                print("Nombre:", dato["nombre"])
                print("Especialidad:", dato["especialidad"])
                print("Proyectos:", dato["proyectos"])

                encontrado = True

        if encontrado == False:
            print("IA: Investigador no encontrado.")

    # OPCION 4
    elif opcion == "4":

        cambiar = input("\nNombre del investigador a actualizar: ")

        actualizado = False

        for dato in investigadores:

            if dato["nombre"] == cambiar:

                nueva = input("Nueva especialidad: ")

                dato["especialidad"] = nueva

                print("IA: Especialidad actualizada.")

                actualizado = True

        if actualizado == False:
            print("Investigador no encontrado.")

    # OPCION 5
    elif opcion == "5":

        eliminar = input("\nNombre del investigador a eliminar: ")

        eliminado = False

        for dato in investigadores:

            if dato["nombre"] == eliminar:

                investigadores.remove(dato)

                print("IA: Investigador eliminado.")

                eliminado = True

        if eliminado == False:
            print("Investigador no encontrado.")

    # OPCION 6
    elif opcion == "6":

        print("\nGracias por usar el sistema IA.")
        break

    # OPCION INVALIDA
    else:

        print("\nOpcion no valida.")
# Out:
# ...
#    SISTEMA IA DE INVESTIGADORES
# ...
#
# ========= MENU =========
# 1. Registrar investigador
# 2. Mostrar investigadores
# 3. Buscar investigador
# 4. Actualizar especialidad
# 5. Eliminar investigador
# 6. Salir
#
# Selecciona una opcion: 1
#
# --- REGISTRO DE INVESTIGADOR ---
# Nombre del investigador: alex
# Especialidad: robotica
# Cantidad de proyectos: 5
#
# IA: Investigador registrado correctamente.
#
# ========= MENU =========
# 1. Registrar investigador
# 2. Mostrar investigadores
# 3. Buscar investigador
# 4. Actualizar especialidad
# 5. Eliminar investigador
# 6. Salir
#
# Selecciona una opcion: 1
#
# --- REGISTRO DE INVESTIGADOR ---
# Nombre del investigador: Cristopher
# Especialidad: Inteligencia artificial
# Cantidad de proyectos: 8
#
# IA: Investigador registrado correctamente.
#
# ========= MENU =========
# 1. Registrar investigador
# 2. Mostrar investigadores
# 3. Buscar investigador
# 4. Actualizar especialidad
# 5. Eliminar investigador
# 6. Salir
#
# ...

# %% [markdown]
# ![](https://raw.githubusercontent.com/CristopherLopez67/-UIII-Act-10-Proyecto-de-simulaci-n-de-inteligencia-artificial-Cristopher-1374/refs/heads/main/infoinves.png)
